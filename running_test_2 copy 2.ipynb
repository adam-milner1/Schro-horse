# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
from tensorflow.keras import (
    layers,
    models,
    callbacks,
    losses,
    utils,
    metrics,
    optimizers,
)

from functions.model2 import GAN
import datetime
import json
from functions.data_preperation import process_model_data
from functions.q_generator import no_entangly_circuit_tickers

# %%
def shuffle_data(feature_data, real_data):
    # feature_data: numpy array
    # real_data: tf.Tensor

    # Make sure we have the same number of samples
    assert feature_data.shape[0] == real_data.shape[0], "Mismatched number of samples"

    # Generate shuffled indices
    indices = np.arange(feature_data.shape[0])
    np.random.shuffle(indices)

    # Apply to both
    feature_shuffled = feature_data[indices]
    real_shuffled = tf.gather(real_data, indices)

    return feature_shuffled, real_shuffled

# %%
DISCRIMINATOR_STEPS = 5
DISCRIMINATOR_LAYER_MULTIPLIER =2
GP_WEIGHT = 10
LEARNING_RATE = 1e-5
ADAM_BETA_1 = 0.5
ADAM_BETA_2 = 0.9
BATCH_SIZE = 32
EPOCHS = 100
D_OPTIMIZER = optimizers.Adam(learning_rate=LEARNING_RATE, beta_1 = ADAM_BETA_1, beta_2 = ADAM_BETA_2)
#G_OPTIMIZER = optimizers.Adam(learning_rate=LEARNING_RATE, beta_1 = ADAM_BETA_1, beta_2 = ADAM_BETA_2)

# %% [markdown]
# ## Load data

# %%
targets = ["OC_next", "CO_next"]
features = ["Close", "High", "Low", "Open", "Volume", "MACD", "Signal_Line", "EMA_20"]
tickers = ['GOOG','AAPL','MSFT','AMZN']

# %%
train_data = process_model_data(targets, features, tickers)  # feature_data, target_data

y = train_data[1]

plt.scatter(y[:, 0], y[:, 2], alpha=0.7)
plt.xlabel('GOOG OC_next')
plt.ylabel('AAPL OC_next')
plt.title('AAPL vs GOOG')
plt.grid(True)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# /Users/a01milner/Documents/Schro-horse/functions/data_preperation.py:16: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# /Users/a01milner/Documents/Schro-horse/functions/data_preperation.py:16: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# /Users/a01milner/Documents/Schro-horse/functions/data_preperation.py:16: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# (1003, 32) (1003, 8)

# %% [markdown]
# ## Load generator from Qiskit

# %%
qc= no_entangly_circuit_tickers(tickers)
print(len(list(qc.parameters)))
qc.draw('mpl')
# Out:
# 82

# %%
qgan = GAN(
    discriminator_steps= DISCRIMINATOR_STEPS,
    gp_weight= GP_WEIGHT,
    n_tickers= len(tickers),
    n_features= len(features),
    n_outputs= len(targets),
    generator_qiskit=qc,
    discriminator_layer_multiplier=DISCRIMINATOR_LAYER_MULTIPLIER,
    on_hardware= False,
    batch_size= BATCH_SIZE,
)

qgan.compile(
    d_optimizer = D_OPTIMIZER,
    
)
# Out:
# Trial 2Q Depth: 3
# /Users/a01milner/Documents/Schro-horse/.venv/lib/python3.10/site-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %%
#os.mkdir("models/")
time = datetime.datetime.now().strftime("%d%m.%H%M")
model_path = f"models/no_entangly"
os.mkdir(model_path)

# %%
import os
import numpy as np
import json
from tensorflow.keras.callbacks import Callback

class SaveWeightsAndMetrics(Callback):
    def __init__(self, qgan, save_dir="checkpoints", save_weights=True, save_metrics=True):
        super().__init__()
        self.qgan = qgan   # <-- store GAN object here
        self.save_dir = save_dir
        self.save_weights = save_weights
        self.save_metrics = save_metrics
        os.makedirs(save_dir, exist_ok=True)

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}

        # Save generator weights
        if self.save_weights:
            weights_path = os.path.join(self.save_dir, f"generator_weights_epoch{epoch+1}.npy")
            weights_list = [w.numpy() for w in self.qgan.generator_weights]
            np.save(weights_path, weights_list)
            print(f"✅ Saved generator weights to {weights_path}")

        # Save metrics
        if self.save_metrics:
            metrics_path = os.path.join(self.save_dir, f"metrics_epoch{epoch+1}.json")
            with open(metrics_path, "w") as f:
                json.dump({k: float(v) for k, v in logs.items()}, f, indent=2)
            print(f"📊 Saved metrics to {metrics_path}")

# %%
callbacks = [
    SaveWeightsAndMetrics(qgan=qgan, save_dir=f"{model_path}/logs")
]

# %%
feature_data, real_data = train_data
feature_data, real_data = shuffle_data(feature_data,real_data)

# %%
qgan.fit(
    feature_data=feature_data.astype(np.float32),
    real_data=real_data,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=callbacks
)
# Out:
# Epoch 1/100 - {'d_loss': 7.123423188924789, 'g_loss': -0.26184930140152574, 'd_gp': 0.6948561854660511, 'd_wass_loss': 0.1748617342673242, 'real_score': 0.08698757411912084, 'gen_score': 0.26184930140152574}
# ✅ Saved generator weights to models/no_entangly/logs/generator_weights_epoch1.npy
# 📊 Saved metrics to models/no_entangly/logs/metrics_epoch1.json
# Epoch 2/100 - {'d_loss': 7.091065317392349, 'g_loss': -0.3327487092465162, 'd_gp': 0.6857038270682096, 'd_wass_loss': 0.23402657406404614, 'real_score': 0.09872216125950217, 'gen_score': 0.3327487092465162}
# ✅ Saved generator weights to models/no_entangly/logs/generator_weights_epoch2.npy
# 📊 Saved metrics to models/no_entangly/logs/metrics_epoch2.json
# Epoch 3/100 - {'d_loss': 6.771967321634293, 'g_loss': -0.3174549927935004, 'd_gp': 0.6567934900522232, 'd_wass_loss': 0.20403282763436437, 'real_score': 0.11342214327305555, 'gen_score': 0.3174549927935004}
# ✅ Saved generator weights to models/no_entangly/logs/generator_weights_epoch3.npy
# 📊 Saved metrics to models/no_entangly/logs/metrics_epoch3.json
# Epoch 4/100 - {'d_loss': 6.563866809010506, 'g_loss': -0.31452829390764236, 'd_gp': 0.6381374001502991, 'd_wass_loss': 0.18249347805976868, 'real_score': 0.1320347893051803, 'gen_score': 0.31452829390764236}
# ✅ Saved generator weights to models/no_entangly/logs/generator_weights_epoch4.npy
# 📊 Saved metrics to models/no_entangly/logs/metrics_epoch4.json
# Epoch 5/100 - {'d_loss': 6.432921886444092, 'g_loss': -0.3227520231157541, 'd_gp': 0.6265645921230316, 'd_wass_loss': 0.16727613424882293, 'real_score': 0.1554758818820119, 'gen_score': 0.3227520231157541}
# ✅ Saved generator weights to models/no_entangly/logs/generator_weights_epoch5.npy
# 📊 Saved metrics to models/no_entangly/logs/metrics_epoch5.json
# Epoch 6/100 - {'d_loss': 6.223611116409302, 'g_loss': -0.36019662488251925, 'd_gp': 0.6045161057263613, 'd_wass_loss': 0.17845007590949535, 'real_score': 0.18174653174355626, 'gen_score': 0.36019662488251925}
# ✅ Saved generator weights to models/no_entangly/logs/generator_weights_epoch6.npy
# 📊 Saved metrics to models/no_entangly/logs/metrics_epoch6.json
# Epoch 7/100 - {'d_loss': 6.011838883161545, 'g_loss': -0.48851420916616917, 'd_gp': 0.5730102863162756, 'd_wass_loss': 0.2817363515496254, 'real_score': 0.20677785528823733, 'gen_score': 0.48851420916616917}
# ✅ Saved generator weights to models/no_entangly/logs/generator_weights_epoch7.npy
# 📊 Saved metrics to models/no_entangly/logs/metrics_epoch7.json
# Epoch 8/100 - {'d_loss': 5.624462693929672, 'g_loss': -0.5093447379767895, 'd_gp': 0.5348327234387398, 'd_wass_loss': 0.2761358432471752, 'real_score': 0.2332088598050177, 'gen_score': 0.5093447379767895}
# ✅ Saved generator weights to models/no_entangly/logs/generator_weights_epoch8.npy
# 📊 Saved metrics to models/no_entangly/logs/metrics_epoch8.json
# Epoch 9/100 - {'d_loss': 5.277359202504158, 'g_loss': -0.5142535613849759, 'd_gp': 0.5026691872626543, 'd_wass_loss': 0.250667208340019, 'real_score': 0.26358638145029545, 'gen_score': 0.5142535613849759}
# ✅ Saved generator weights to models/no_entangly/logs/generator_weights_epoch9.npy
# 📊 Saved metrics to models/no_entangly/logs/metrics_epo

# ✅ Saved generator weights to models/no_entangly/logs/generator_weights_epoch21.npy
# 📊 Saved metrics to models/no_entangly/logs/metrics_epoch21.json
# Epoch 22/100 - {'d_loss': 1.1334625110030174, 'g_loss': -1.4729926697909832, 'd_gp': 0.07992900966200978, 'd_wass_loss': 0.3341723820194602, 'real_score': 1.1388203613460064, 'gen_score': 1.4729926697909832}
# ✅ Saved generator weights to models/no_entangly/logs/generator_weights_epoch22.npy
# 📊 Saved metrics to models/no_entangly/logs/metrics_epoch22.json
# Epoch 23/100 - {'d_loss': 1.033953195437789, 'g_loss': -1.487557791173458, 'd_gp': 0.07444097753614187, 'd_wass_loss': 0.2895434256643057, 'real_score': 1.198014385998249, 'gen_score': 1.487557791173458}
# ✅ Saved generator weights to models/no_entangly/logs/generator_weights_epoch23.npy
# 📊 Saved metrics to models/no_entangly/logs/metrics_epoch23.json
# Epoch 24/100 - {'d_loss': 1.2734544351696968, 'g_loss': -1.7074495404958725, 'd_gp': 0.07983040227554739, 'd_wass_loss': 0.4751504398882389, 'real_score': 1.2322991415858269, 'gen_score': 1.7074495404958725}
# ✅ Saved generator weights to models/no_entangly/logs/generator_weights_epoch24.npy
# 📊 Saved metrics to models/no_entangly/logs/metrics_epoch24.json
# Epoch 25/100 - {'d_loss': 1.1142899431288242, 'g_loss': -1.6417613588273525, 'd_gp': 0.0738380360417068, 'd_wass_loss': 0.37590963672846556, 'real_score': 1.2658518254756927, 'gen_score': 1.6417613588273525}
# ✅ Saved generator weights to models/no_entangly/logs/generator_weights_epoch25.npy
# 📊 Saved metrics to models/no_entangly/logs/metrics_epoch25.json
# Epoch 26/100 - {'d_loss': 1.1248587537556887, 'g_loss': -1.6061593629419804, 'd_gp': 0.08092630445025861, 'd_wass_loss': 0.3155957469716668, 'real_score': 1.2905635237693787, 'gen_score': 1.6061593629419804}
# ✅ Saved generator weights to models/no_entangly/logs/generator_weights_epoch26.npy
# 📊 Saved metrics to models/no_entangly/logs/metrics_epoch26.json
# Epoch 27/100 - {'d_loss': 1.0005694404244423, 'g_loss': -1.5717159025371075, 'd_gp': 0.07397194916848093, 'd_wass_loss': 0.26084984512999654, 'real_score': 1.3108660839498043, 'gen_score': 1.5717159025371075}
# ✅ Saved generator weights to models/no_entangly/logs/generator_weights_epoch27.npy
# 📊 Saved metrics to models/no_entangly/logs/metrics_epoch27.json
# Epoch 28/100 - {'d_loss': 0.9582042824476957, 'g_loss': -1.626681912690401, 'd_gp': 0.06566300278063864, 'd_wass_loss': 0.3015742851421237, 'real_score': 1.3251076191663742, 'gen_score': 1.626681912690401}
# ✅ Saved generator weights to models/no_entangly/logs/generator_weights_epoch28.npy
# 📊 Saved metrics to models/no_entangly/logs/metrics_epoch28.json
# Epoch 29/100 - {'d_loss': 0.8378390092402697, 'g_loss': -1.5398450903594494, 'd_gp': 0.06287485535722226, 'd_wass_loss': 0.20909041306003928, 'real_score': 1.330754704773426, 'gen_score': 1.5398450903594494}
# ✅ Saved generator weights to models/no_entangly/logs/generator_weights_epoch29.npy
# 📊 Saved metrics to models/no_entangly/logs/metrics_epoch29.json
# Epoch 30/100 - {'d_loss': 0.8335292069241405, 'g_loss': -1.4881500378251076, 'd_gp': 0.06739681866019964, 'd_wass_loss': 0.15956109575927258, 'real_score': 1.3285889141261578, 'gen_score': 1.4881500378251076}
# ✅ Saved generator weights to models/no_entangly/logs/generator_weights_epoch30.npy
# 📊 Saved metrics to models/no_entangly/logs/metrics_epoch30.json
# Epoch 31/100 - {'d_loss': 1.0915574468672276, 'g_loss': -1.570165477693081, 'd_gp': 0.08564149227458984, 'd_wass_loss': 0.23514249129220843, 'real_score': 1.3350228853523731, 'gen_score': 1.570165477693081}
# ✅ Saved generator weights to models/no_entangly/logs/generator_weights_epoch31.npy
# 📊 Saved metrics to models/no_entangly/logs/metrics_epoch31.json

# %%
qgan.generator_save(f"{model_path}/generator.npy") 
qgan.discriminator.save(f"{model_path}/discriminator.keras")
# Out:
# Generator weights saved to models/models_0310.0109/generator.npy
