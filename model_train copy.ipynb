# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
from tensorflow.keras import (
    layers,
    models,
    callbacks,
    losses,
    utils,
    metrics,
    optimizers,
)

from functions.model2 import GAN
import datetime
import json
from functions.data_preperation import process_model_data_four
from functions.q_generator import four_qubit_circuit_tickers
# Out:
# 2.16.2
# GPU devices: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
def shuffle_data(feature_data, real_data):
    # feature_data: numpy array
    # real_data: tf.Tensor

    # Make sure we have the same number of samples
    assert feature_data.shape[0] == real_data.shape[0], "Mismatched number of samples"

    # Generate shuffled indices
    indices = np.arange(feature_data.shape[0])
    np.random.shuffle(indices)

    # Apply to both
    feature_shuffled = feature_data[indices]
    real_shuffled = tf.gather(real_data, indices)

    return feature_shuffled, real_shuffled

# %%
DISCRIMINATOR_STEPS = 5
DISCRIMINATOR_LAYER_MULTIPLIER =2
GP_WEIGHT = 10
LEARNING_RATE = 1e-5
ADAM_BETA_1 = 0.5
ADAM_BETA_2 = 0.9
BATCH_SIZE = 32
EPOCHS = 100
D_OPTIMIZER = optimizers.Adam(learning_rate=LEARNING_RATE, beta_1 = ADAM_BETA_1, beta_2 = ADAM_BETA_2)
#G_OPTIMIZER = optimizers.Adam(learning_rate=LEARNING_RATE, beta_1 = ADAM_BETA_1, beta_2 = ADAM_BETA_2)
# Out:
# 2025-10-03 10:32:35.737643: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2 Pro
# 2025-10-03 10:32:35.737665: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-10-03 10:32:35.737672: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2025-10-03 10:32:35.737688: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-10-03 10:32:35.737699: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ## Load data

# %%
targets = ["OC_next", "CO_next","High","Low"]
features = [
    "Close", "High", "Low", "Open", 
    "Volume", "MACD", "Signal_Line", "EMA_20",
    "EMA_50", "SMA_30", "RSI_14", "ATR_14",
    "prev_High", "prev_Low", "prev_Close", "prev_Open"
]
tickers = ['GOOG','AAPL']

# %%
train_data = process_model_data_four(targets, features, tickers)  # feature_data, target_data

y = train_data[1]

plt.scatter(y[:, 0], y[:, 4], alpha=0.7)
plt.xlabel('GOOG OC_next')
plt.ylabel('AAPL OC_next')
plt.title('AAPL vs GOOG')
plt.grid(True)
plt.show()
# Out:
# /Users/a01milner/Documents/Schro-horse/functions/data_preperation.py:16: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# /Users/a01milner/Documents/Schro-horse/functions/data_preperation.py:16: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# (980, 32) (980, 8)

# %% [markdown]
# ## Load generator from Qiskit

# %%
qc= four_qubit_circuit_tickers(tickers)
print(len(list(qc.parameters)))
qc.draw('mpl')
# Out:
# 80

# %%
qgan = GAN(
    discriminator_steps= DISCRIMINATOR_STEPS,
    gp_weight= GP_WEIGHT,
    n_tickers= len(tickers),
    n_features= len(features),
    n_outputs= len(targets),
    generator_qiskit=qc,
    discriminator_layer_multiplier=DISCRIMINATOR_LAYER_MULTIPLIER,
    on_hardware= False,
    batch_size= BATCH_SIZE,
)

qgan.compile(
    d_optimizer = D_OPTIMIZER,
    
)
# Out:
# Trial 2Q Depth: 12
# /Users/a01milner/Documents/Schro-horse/.venv/lib/python3.10/site-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %%
#os.mkdir("models/")
time = datetime.datetime.now().strftime("%d%m.%H%M")
model_path = f"models/4Qubitperticker"
os.mkdir(model_path)

# %%
import os
import numpy as np
import json
from tensorflow.keras.callbacks import Callback

class SaveWeightsAndMetrics(Callback):
    def __init__(self, qgan, save_dir="checkpoints", save_weights=True, save_metrics=True):
        super().__init__()
        self.qgan = qgan   # <-- store GAN object here
        self.save_dir = save_dir
        self.save_weights = save_weights
        self.save_metrics = save_metrics
        os.makedirs(save_dir, exist_ok=True)

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}

        # Save generator weights
        if self.save_weights:
            weights_path = os.path.join(self.save_dir, f"generator_weights_epoch{epoch+1}.npy")
            weights_list = [w.numpy() for w in self.qgan.generator_weights]
            np.save(weights_path, weights_list)
            print(f"✅ Saved generator weights to {weights_path}")

        # Save metrics
        if self.save_metrics:
            metrics_path = os.path.join(self.save_dir, f"metrics_epoch{epoch+1}.json")
            with open(metrics_path, "w") as f:
                json.dump({k: float(v) for k, v in logs.items()}, f, indent=2)
            print(f"📊 Saved metrics to {metrics_path}")

# %%
callbacks = [
    SaveWeightsAndMetrics(qgan=qgan, save_dir=f"{model_path}/logs")
]

# %%
feature_data, real_data = train_data
feature_data, real_data = shuffle_data(feature_data,real_data)

# %%
qgan.fit(
    feature_data=feature_data.astype(np.float32),
    real_data=real_data,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=callbacks
)
# Out:
# Epoch 1/100 - {'d_loss': 7.680725759075534, 'g_loss': -0.00833942933428672, 'd_gp': 0.7668552110272069, 'd_wass_loss': 0.012173482091560389, 'real_score': -0.00383405267230926, 'gen_score': 0.00833942933428672}
# ✅ Saved generator weights to models/4Qubitperticker/logs/generator_weights_epoch1.npy
# 📊 Saved metrics to models/4Qubitperticker/logs/metrics_epoch1.json
# Epoch 2/100 - {'d_loss': 7.669451528979886, 'g_loss': -0.049810658659665816, 'd_gp': 0.7624812068477753, 'd_wass_loss': 0.044639676328628294, 'real_score': 0.0051709797849217734, 'gen_score': 0.049810658659665816}
# ✅ Saved generator weights to models/4Qubitperticker/logs/generator_weights_epoch2.npy
# 📊 Saved metrics to models/4Qubitperticker/logs/metrics_epoch2.json
# Epoch 3/100 - {'d_loss': 7.488089822953747, 'g_loss': -0.08250140783286863, 'd_gp': 0.7419361683630175, 'd_wass_loss': 0.06872842196495302, 'real_score': 0.013772982277817303, 'gen_score': 0.08250140783286863}
# ✅ Saved generator weights to models/4Qubitperticker/logs/generator_weights_epoch3.npy
# 📊 Saved metrics to models/4Qubitperticker/logs/metrics_epoch3.json
# Epoch 4/100 - {'d_loss': 7.151628801899571, 'g_loss': -0.10426990086993863, 'd_gp': 0.7066449061516793, 'd_wass_loss': 0.08517919649039546, 'real_score': 0.019090705400993748, 'gen_score': 0.10426990086993863}
# ✅ Saved generator weights to models/4Qubitperticker/logs/generator_weights_epoch4.npy
# 📊 Saved metrics to models/4Qubitperticker/logs/metrics_epoch4.json
# Epoch 5/100 - {'d_loss': 7.028821191480083, 'g_loss': -0.11037207539043119, 'd_gp': 0.6941207205095599, 'd_wass_loss': 0.08761394528612014, 'real_score': 0.022758123404797045, 'gen_score': 0.11037207539043119}
# ✅ Saved generator weights to models/4Qubitperticker/logs/generator_weights_epoch5.npy
# 📊 Saved metrics to models/4Qubitperticker/logs/metrics_epoch5.json
# Epoch 6/100 - {'d_loss': 6.793774866288708, 'g_loss': -0.12441457111027933, 'd_gp': 0.669607808513026, 'd_wass_loss': 0.09769672107311987, 'real_score': 0.02671785742765473, 'gen_score': 0.12441457111027933}
# ✅ Saved generator weights to models/4Qubitperticker/logs/generator_weights_epoch6.npy
# 📊 Saved metrics to models/4Qubitperticker/logs/metrics_epoch6.json
# Epoch 7/100 - {'d_loss': 6.55716771464194, 'g_loss': -0.14090169942186725, 'd_gp': 0.6448268313561717, 'd_wass_loss': 0.10889955754241636, 'real_score': 0.03200214356184006, 'gen_score': 0.14090169942186725}
# ✅ Saved generator weights to models/4Qubitperticker/logs/generator_weights_epoch7.npy
# 📊 Saved metrics to models/4Qubitperticker/logs/metrics_epoch7.json
# Epoch 8/100 - {'d_loss': 6.2438713812058975, 'g_loss': -0.15821934563498344, 'd_gp': 0.6124192476272583, 'd_wass_loss': 0.11967833147894952, 'real_score': 0.03854101679978832, 'gen_score': 0.15821934563498344}
# ✅ Saved generator weights to models/4Qubitperticker/logs/generator_weights_epo

# ✅ Saved generator weights to models/4Qubitperticker/logs/generator_weights_epoch70.npy
# 📊 Saved metrics to models/4Qubitperticker/logs/metrics_epoch70.json
# Epoch 71/100 - {'d_loss': 1.5812564934453657, 'g_loss': -0.487460853592042, 'd_gp': 0.1644533995178438, 'd_wass_loss': -0.06327759270225802, 'real_score': 0.550738392337676, 'gen_score': 0.487460853592042}
# ✅ Saved generator weights to models/4Qubitperticker/logs/generator_weights_epoch71.npy
# 📊 Saved metrics to models/4Qubitperticker/logs/metrics_epoch71.json
# Epoch 72/100 - {'d_loss': 1.326400218471404, 'g_loss': -0.5433788732174905, 'd_gp': 0.13302609132182214, 'd_wass_loss': -0.00386072558534755, 'real_score': 0.5472396410280659, 'gen_score': 0.5433788732174905}
# ✅ Saved generator weights to models/4Qubitperticker/logs/generator_weights_epoch72.npy
# 📊 Saved metrics to models/4Qubitperticker/logs/metrics_epoch72.json
# Epoch 73/100 - {'d_loss': 1.745408215830403, 'g_loss': -0.5086564075562262, 'd_gp': 0.17793900375404664, 'd_wass_loss': -0.03398196597493464, 'real_score': 0.5426383508789924, 'gen_score': 0.5086564075562262}
# ✅ Saved generator weights to models/4Qubitperticker/logs/generator_weights_epoch73.npy
# 📊 Saved metrics to models/4Qubitperticker/logs/metrics_epoch73.json
# Epoch 74/100 - {'d_loss': 1.4405175947373914, 'g_loss': -0.49466831741794465, 'd_gp': 0.14813802992143937, 'd_wass_loss': -0.04086267479485081, 'real_score': 0.5355310488131738, 'gen_score': 0.49466831741794465}
# ✅ Saved generator weights to models/4Qubitperticker/logs/generator_weights_epoch74.npy
# 📊 Saved metrics to models/4Qubitperticker/logs/metrics_epoch74.json
# Epoch 75/100 - {'d_loss': 1.2737299626873386, 'g_loss': -0.4737312409185594, 'd_gp': 0.1342959747679772, 'd_wass_loss': -0.0692298210436298, 'real_score': 0.5429610956099725, 'gen_score': 0.4737312409185594}
# ✅ Saved generator weights to models/4Qubitperticker/logs/generator_weights_epoch75.npy
# 📊 Saved metrics to models/4Qubitperticker/logs/metrics_epoch75.json
# Epoch 76/100 - {'d_loss': 1.5701606389014953, 'g_loss': -0.4588264246140757, 'd_gp': 0.16574865243127268, 'd_wass_loss': -0.08732594814031355, 'real_score': 0.5461523667458565, 'gen_score': 0.4588264246140757}
# ✅ Saved generator weights to models/4Qubitperticker/logs/generator_weights_epoch76.npy
# 📊 Saved metrics to models/4Qubitperticker/logs/metrics_epoch76.json
# Epoch 77/100 - {'d_loss': 1.2888250889316681, 'g_loss': -0.4769944510152263, 'd_gp': 0.13620412541973975, 'd_wass_loss': -0.07321621093057817, 'real_score': 0.5502106460832781, 'gen_score': 0.4769944510152263}
# ✅ Saved generator weights to models/4Qubitperticker/logs/generator_weights_epoch77.npy
# 📊 Saved metrics to models/4Qubitperticker/logs/metrics_epoch77.json
# Epoch 78/100 - {'d_loss': 1.4764672940777195, 'g_loss': -0.4695910051945717, 'd_gp': 0.15624732740463748, 'd_wass_loss': -0.08600605351309623, 'real_score': 0.55559705726562, 'gen_score': 0.4695910051945717}
# ✅ Saved generator weights to models/4Qubitperticker/logs/generator_weights_epoch78.npy
# 📊 Saved metrics to models/4Qubitperticker/logs/metrics_epoch78.json
# Epoch 79/100 - {'d_loss': 1.3349222771583065, 'g_loss': -0.5074340306943462, 'd_gp': 0.13854535428747053, 'd_wass_loss': -0.050531277012440465, 'real_score': 0.5579653709165512, 'gen_score': 0.5074340306943462}
# ✅ Saved generator weights to models/4Qubitperticker/logs/generator_weights_epoch79.npy
# 📊 Saved metrics to models/4Qubitperticker/logs/metrics_epoch79.json
# Epoch 80/100 - {'d_loss': 1.7709155813340218, 'g_loss': -0.4853311729046606, 'd_gp': 0.18374033656812483, 'd_wass_loss': -0.06648762355889043, 'real_score': 0.5518187476742652, 'gen_score': 0.4853311729046606}
# ✅ Saved generator weights to models/4Qubitperticker/logs/generator_weights_epoch80.npy
# 📊 Saved metrics to models/4Qubitperticker/logs/metrics_epoch80.json
# Epoch 81/100 - {'d_loss': 1.6848053778371503, 'g_loss': -0.47822734521281335, 'd_gp': 0.17613494396209717, 'd_wass_loss': -0.07654389955343739, 'real_score': 0.5547712406804485, 'gen_score': 0.47822734521281335}
# ✅ Saved generator weights to models/4Qubitperticker/logs/generator_weights_epoch81.npy
# 📊 Saved metrics to models/4Qubitperticker/logs/metrics_epoch81.json

# %%
qgan.generator_save(f"{model_path}/generator.npy") 
qgan.discriminator.save(f"{model_path}/discriminator.keras")
# Out:
# Generator weights saved to models/models_0310.0109/generator.npy
