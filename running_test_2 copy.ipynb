# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
from tensorflow.keras import (
    layers,
    models,
    callbacks,
    losses,
    utils,
    metrics,
    optimizers,
)

from functions.model2 import GAN
import datetime
import json
from functions.data_preperation import process_model_data_entangly
from functions.q_generator import entangly_circuit_tickers
# Out:
# 2.16.2
# GPU devices: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
def shuffle_data(feature_data, real_data):
    # feature_data: numpy array
    # real_data: tf.Tensor

    # Make sure we have the same number of samples
    assert feature_data.shape[0] == real_data.shape[0], "Mismatched number of samples"

    # Generate shuffled indices
    indices = np.arange(feature_data.shape[0])
    np.random.shuffle(indices)

    # Apply to both
    feature_shuffled = feature_data[indices]
    real_shuffled = tf.gather(real_data, indices)

    return feature_shuffled, real_shuffled

# %%
DISCRIMINATOR_STEPS = 5
DISCRIMINATOR_LAYER_MULTIPLIER =2
GP_WEIGHT = 10
LEARNING_RATE = 1e-5
ADAM_BETA_1 = 0.5
ADAM_BETA_2 = 0.9
BATCH_SIZE = 32
EPOCHS = 100
D_OPTIMIZER = optimizers.Adam(learning_rate=LEARNING_RATE, beta_1 = ADAM_BETA_1, beta_2 = ADAM_BETA_2)
#G_OPTIMIZER = optimizers.Adam(learning_rate=LEARNING_RATE, beta_1 = ADAM_BETA_1, beta_2 = ADAM_BETA_2)
# Out:
# 2025-10-03 13:09:57.824516: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2 Pro
# 2025-10-03 13:09:57.824553: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-10-03 13:09:57.824560: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2025-10-03 13:09:57.824579: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-10-03 13:09:57.824593: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ## Load data

# %%
targets = ["OC_next", "CO_next"]
features = ["Close", "High", "Low", "Open", "Volume", "MACD", "Signal_Line", "EMA_20"]
tickers = ['GOOG','AAPL','MSFT','AMZN']

# %%
train_data = process_model_data_entangly(targets, features, tickers)  # feature_data, target_data

y = train_data[1]
data = train_data[2] 

plt.scatter(y[:, 0], y[:, 2], alpha=0.7)
plt.xlabel('GOOG OC_next')
plt.ylabel('AAPL OC_next')
plt.title('AAPL vs GOOG')
plt.grid(True)
plt.show()
# Out:
# /Users/a01milner/Documents/Schro-horse/functions/data_preperation.py:16: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# /Users/a01milner/Documents/Schro-horse/functions/data_preperation.py:16: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# /Users/a01milner/Documents/Schro-horse/functions/data_preperation.py:16: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# /Users/a01milner/Documents/Schro-horse/functions/data_preperation.py:16: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# /Users/a01milner/Documents/Schro-horse/functions/data_preperation.py:16: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, start=start_date, end=end_date)
# [*********************100%***********************]  4 of 4 completed
# (1003, 32) (1003, 8)
# /Users/a01milner/Documents/Schro-horse/functions/data_preperation.py:217: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   X = df.drop(columns=target_cols)

# %% [markdown]
# ## Load generator from Qiskit

# %%
qc= entangly_circuit_tickers(tickers, data)
print(len(list(qc.parameters)))
qc.draw('mpl')
# Out:
# [('GOOG', 'MSFT'), ('GOOG', 'AMZN'), ('MSFT', 'AAPL'), ('MSFT', 'AMZN'), ('AMZN', 'AAPL')]
# [('AMZN', 'GOOG'), ('AMZN', 'AAPL'), ('AMZN', 'MSFT'), ('GOOG', 'MSFT'), ('GOOG', 'AAPL'), ('MSFT', 'AAPL')]
# 82

# %%
qgan = GAN(
    discriminator_steps= DISCRIMINATOR_STEPS,
    gp_weight= GP_WEIGHT,
    n_tickers= len(tickers),
    n_features= len(features),
    n_outputs= len(targets),
    generator_qiskit=qc,
    discriminator_layer_multiplier=DISCRIMINATOR_LAYER_MULTIPLIER,
    on_hardware= False,
    batch_size= BATCH_SIZE,
)

qgan.compile(
    d_optimizer = D_OPTIMIZER,
    
)
# Out:
# Trial 2Q Depth: 14
# /Users/a01milner/Documents/Schro-horse/.venv/lib/python3.10/site-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %%
#os.mkdir("models/")
time = datetime.datetime.now().strftime("%d%m.%H%M")
model_path = f"models/entangly"
os.mkdir(model_path)

# %%
import os
import numpy as np
import json
from tensorflow.keras.callbacks import Callback

class SaveWeightsAndMetrics(Callback):
    def __init__(self, qgan, save_dir="checkpoints", save_weights=True, save_metrics=True):
        super().__init__()
        self.qgan = qgan   # <-- store GAN object here
        self.save_dir = save_dir
        self.save_weights = save_weights
        self.save_metrics = save_metrics
        os.makedirs(save_dir, exist_ok=True)

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}

        # Save generator weights
        if self.save_weights:
            weights_path = os.path.join(self.save_dir, f"generator_weights_epoch{epoch+1}.npy")
            weights_list = [w.numpy() for w in self.qgan.generator_weights]
            np.save(weights_path, weights_list)
            print(f"✅ Saved generator weights to {weights_path}")

        # Save metrics
        if self.save_metrics:
            metrics_path = os.path.join(self.save_dir, f"metrics_epoch{epoch+1}.json")
            with open(metrics_path, "w") as f:
                json.dump({k: float(v) for k, v in logs.items()}, f, indent=2)
            print(f"📊 Saved metrics to {metrics_path}")

# %%
callbacks = [
    SaveWeightsAndMetrics(qgan=qgan, save_dir=f"{model_path}/logs")
]

# %%
feature_data, real_data,_ = train_data
feature_data, real_data = shuffle_data(feature_data,real_data)

# %%
qgan.fit(
    feature_data=feature_data.astype(np.float32),
    real_data=real_data,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=callbacks
)
# Out:
# Epoch 1/100 - {'d_loss': 3.3480956479907036, 'g_loss': 0.4078752975910902, 'd_gp': 0.28902061842381954, 'd_wass_loss': 0.45788927283138037, 'real_score': -0.8657645415514708, 'gen_score': -0.4078752975910902}
# ✅ Saved generator weights to models/entangly/logs/generator_weights_epoch1.npy
# 📊 Saved metrics to models/entangly/logs/metrics_epoch1.json
# Epoch 2/100 - {'d_loss': 3.3956408947706223, 'g_loss': 0.27006186731159687, 'd_gp': 0.2932755220681429, 'd_wass_loss': 0.4628855148330331, 'real_score': -0.7329474240541458, 'gen_score': -0.27006186731159687}
# ✅ Saved generator weights to models/entangly/logs/generator_weights_epoch2.npy
# 📊 Saved metrics to models/entangly/logs/metrics_epoch2.json
# Epoch 3/100 - {'d_loss': 3.0761548802256584, 'g_loss': 0.31197000946849585, 'd_gp': 0.27395379077643156, 'd_wass_loss': 0.33661670330911875, 'real_score': -0.6485867034643888, 'gen_score': -0.31197000946849585}
# ✅ Saved generator weights to models/entangly/logs/generator_weights_epoch3.npy
# 📊 Saved metrics to models/entangly/logs/metrics_epoch3.json
# Epoch 4/100 - {'d_loss': 2.9127634912729263, 'g_loss': 0.3525995593518019, 'd_gp': 0.26403126446530223, 'd_wass_loss': 0.27245088247582316, 'real_score': -0.6250503845512867, 'gen_score': -0.3525995593518019}
# ✅ Saved generator weights to models/entangly/logs/generator_weights_epoch4.npy
# 📊 Saved metrics to models/entangly/logs/metrics_epoch4.json
# Epoch 5/100 - {'d_loss': 2.7428441122174263, 'g_loss': 0.3948742728680372, 'd_gp': 0.2512505669146776, 'd_wass_loss': 0.23033843003213406, 'real_score': -0.6252127513289452, 'gen_score': -0.3948742728680372}
# ✅ Saved generator weights to models/entangly/logs/generator_weights_epoch5.npy
# 📊 Saved metrics to models/entangly/logs/metrics_epoch5.json
# Epoch 6/100 - {'d_loss': 2.695057511329651, 'g_loss': 0.4491877807304263, 'd_gp': 0.25094402115792036, 'd_wass_loss': 0.1856171595863998, 'real_score': -0.6348049640655518, 'gen_score': -0.4491877807304263}
# ✅ Saved generator weights to models/entangly/logs/generator_weights_epoch6.npy
# 📊 Saved metrics to models/entangly/logs/metrics_epoch6.json
# Epoch 7/100 - {'d_loss': 2.6065414622426033, 'g_loss': 0.5208529960364103, 'd_gp': 0.24692948395386338, 'd_wass_loss': 0.13724659965373576, 'real_score': -0.6580995600670576, 'gen_score': -0.5208529960364103}
# ✅ Saved generator weights to models/entangly/logs/generator_weights_epoch7.npy
# 📊 Saved metrics to models/entangly/logs/metrics_epoch7.json
# Epoch 8/100 - {'d_loss': 2.4609401002526283, 'g_loss': 0.5995395015925169, 'd_gp': 0.23733860114589334, 'd_wass_loss': 0.08755393885076046, 'real_score': -0.6870933957397938, 'gen_score': -0.5995395015925169}
# ✅ Saved generator weights to models/entangly/logs/generator_weights_epoch8.npy
# 📊 Saved metrics to models/entangly/logs/metrics_epo

# ✅ Saved generator weights to models/entangly/logs/generator_weights_epoch21.npy
# 📊 Saved metrics to models/entangly/logs/metrics_epoch21.json
# Epoch 22/100 - {'d_loss': 2.424481563270092, 'g_loss': 0.782780023291707, 'd_gp': 0.24112531635910273, 'd_wass_loss': 0.013228551935753785, 'real_score': -0.7960085645318031, 'gen_score': -0.782780023291707}
# ✅ Saved generator weights to models/entangly/logs/generator_weights_epoch22.npy
# 📊 Saved metrics to models/entangly/logs/metrics_epoch22.json
# Epoch 23/100 - {'d_loss': 2.370662983506918, 'g_loss': 0.7995634842664003, 'd_gp': 0.2353388536721468, 'd_wass_loss': 0.0172745295567438, 'real_score': -0.8168380446732044, 'gen_score': -0.7995634842664003}
# ✅ Saved generator weights to models/entangly/logs/generator_weights_epoch23.npy
# 📊 Saved metrics to models/entangly/logs/metrics_epoch23.json
# Epoch 24/100 - {'d_loss': 2.158511195331812, 'g_loss': 0.782187519595027, 'd_gp': 0.21333132963627577, 'd_wass_loss': 0.02519787210621871, 'real_score': -0.8073853645473719, 'gen_score': -0.782187519595027}
# ✅ Saved generator weights to models/entangly/logs/generator_weights_epoch24.npy
# 📊 Saved metrics to models/entangly/logs/metrics_epoch24.json
# Epoch 25/100 - {'d_loss': 2.440434254705906, 'g_loss': 0.7771788295358419, 'd_gp': 0.24001870723441243, 'd_wass_loss': 0.040247066877782345, 'real_score': -0.8174259159713984, 'gen_score': -0.7771788295358419}
# ✅ Saved generator weights to models/entangly/logs/generator_weights_epoch25.npy
# 📊 Saved metrics to models/entangly/logs/metrics_epoch25.json
# Epoch 26/100 - {'d_loss': 2.1580896601080894, 'g_loss': 0.8072776850312948, 'd_gp': 0.21308232750743628, 'd_wass_loss': 0.02726662758504972, 'real_score': -0.8345443475991488, 'gen_score': -0.8072776850312948}
# ✅ Saved generator weights to models/entangly/logs/generator_weights_epoch26.npy
# 📊 Saved metrics to models/entangly/logs/metrics_epoch26.json
# Epoch 27/100 - {'d_loss': 2.3611420392990112, 'g_loss': 0.7995464950799942, 'd_gp': 0.23362436331808567, 'd_wass_loss': 0.024898306728573516, 'real_score': -0.824444804340601, 'gen_score': -0.7995464950799942}
# ✅ Saved generator weights to models/entangly/logs/generator_weights_epoch27.npy
# 📊 Saved metrics to models/entangly/logs/metrics_epoch27.json
# Epoch 28/100 - {'d_loss': 2.229719862341881, 'g_loss': 0.7887749634683132, 'd_gp': 0.21932093147188425, 'd_wass_loss': 0.03651077579706907, 'real_score': -0.8252856843173504, 'gen_score': -0.7887749634683132}
# ✅ Saved generator weights to models/entangly/logs/generator_weights_epoch28.npy
# 📊 Saved metrics to models/entangly/logs/metrics_epoch28.json
# Epoch 29/100 - {'d_loss': 2.391384318470955, 'g_loss': 0.7746183164417744, 'd_gp': 0.23352628108114004, 'd_wass_loss': 0.05612143501639366, 'real_score': -0.8307397197932005, 'gen_score': -0.7746183164417744}
# ✅ Saved generator weights to models/entangly/logs/generator_weights_epoch29.npy
# 📊 Saved metrics to models/entangly/logs/metrics_epoch29.json
# Epoch 30/100 - {'d_loss': 2.265857107937336, 'g_loss': 0.8010921329259872, 'd_gp': 0.22492372198030353, 'd_wass_loss': 0.016619796282611787, 'real_score': -0.8177119642496109, 'gen_score': -0.8010921329259872}
# ✅ Saved generator weights to models/entangly/logs/generator_weights_epoch30.npy
# 📊 Saved metrics to models/entangly/logs/metrics_epoch30.json
# Epoch 31/100 - {'d_loss': 2.311575308442116, 'g_loss': 0.7733596488833427, 'd_gp': 0.22606620658189058, 'd_wass_loss': 0.05091334867756814, 'real_score': -0.8242730386555195, 'gen_score': -0.7733596488833427}
# ✅ Saved generator weights to models/entangly/logs/generator_weights_epoch31.npy
# 📊 Saved metrics to models/entangly/logs/metrics_epoch31.json
# Epoch 32/100 - {'d_loss': 2.1510841213166714, 'g_loss': 0.8070286083966494, 'd_gp': 0.21235959278419614, 'd_wass_loss': 0.027487868122989312, 'real_score': -0.8345164079219103, 'gen_score': -0.8070286083966494}
# ✅ Saved generator weights to models/entangly/logs/generator_weights_epoch32.npy
# 📊 Saved metrics to models/entangly/logs/metrics_epoch32.json

# %%
qgan.generator_save(f"{model_path}/generator.npy") 
qgan.discriminator.save(f"{model_path}/discriminator.keras")
# Out:
# Generator weights saved to models/models_0310.0109/generator.npy
